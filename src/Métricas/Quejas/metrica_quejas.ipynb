# %% [markdown]
# ## Métrica quejas

# %%
# dudas , al filtrar por fecha te quedas con las quejas emitias ese mes?
# porque tengo repetidos en el campo workflow_id

# %%
from dbconn import querydb, querydbtopandas 
import pandas as pd 
import datetime

# %%
pd.set_option('display.max_columns', 500)

# %%
#con esto veo el mes 11
mayor = "2019-12"
menor = "2019-11"

# %%
df = querydbtopandas(f"""select a11.workflow_id  workflow_id,   
   parafecha.id_tie_mes id_tie_mes,
   a12.SUBMOTIVO_ID  SUBMOTIVO_ID,
   max(a18.detalle)  detalle0,
   max(a127.ger_Descripcion)  detalle1,
   a12.atributo_id  atributo_id,
   max(a113.detalle)  detalle3,
   a11.registro_usuario_max  registro_usuario_max,
   a12.ALTA_FECHA  ALTA_FECHA,
   a11.prepaga  afi_prepaga,
   a11.contra  contra,
   a11.inte  afi_integrante,
   max(a130.desc_afi_nombre)  desc_afi_nombre,
   a11.color_workflow  color_workflow,
   max(case when a11.color_workflow=1 then 'Verde'when a11.color_workflow=2 then 'Amarillo'when a11.color_workflow=3 then 'Naranaja' when a11.color_workflow=4 then 'Rojo'else 'Sin Asignar' end)  strDescripcion,
   a12.solucion  solucion,
   a12.INQUIETUD  INQUIETUD,
   a12.finalizado_comu  finalizado_comu,
   max(case when a12.finalizado_comu=0 then 'Abierto' when a12.finalizado_comu=1 then 'Cerrado' else 'Sin Definir' end)  CustCol_53,
   a19.loca  id_afi_localidad_particular,
   max(a111.deno)  deno,
   a112.provin  id_geo_provincia,
   max(a133.desc_geo_provincia)  desc_geo_provincia,
   a12.lugar_evento  lugar_evento,
   a12.prestad  id_pre_prestador,
   max(a13.desc_pre_nombre)  desc_pre_nombre,
   a14.id_emp_empresa  id_emp_empresa,
   max(a110.desc_emp_empresa)  desc_emp_empresa,
   max(a110.id_emp_ejecutivo_cuenta)  id_emp_ejecutivo_cuenta,
   max(a110.id_emp_cuenta)  id_emp_cuenta,
   a11.registro_usuario_min  reg_username0,
   a110.id_emp_megacuenta  id_emp_megacuenta,
   max(a132.desc_emp_megacuenta)  desc_emp_megacuenta

   from   DBA.CRM_ETAPAS_MIN_MAX a11
   join   DBA.crm_quejas_categ_resol a12
     on   (a11.etapa_id_max = a12.ETAPA_ID)
   join   DBA.d_pre_prestador    a13
     on   (a12.prestad = a13.id_pre_prestador)                 
   join   DBA.ft_pad_padron_iq   a14
     on   (a11.ID_AFI_AFILIADO = a14.id_afiliados)
   join   DBA.d_tie_dia parafecha
     on   (a14.MES=parafecha.id_tie_mes)                
   join   DBA.d_tie_mes_min  a17
     on   (a14.MES = a17.id_tie_mes)
   join   DBA.CRM_SUBMOTIVOS a18
     on   (a12.SUBMOTIVO_ID = a18.SUBMOTIVO_ID and a12.motivo_llamado_id = a18.motivo_id)
   join   DBA.afi_domicilios_contra_v_particular a19
     on   (a11.id_domicilio_part = a19.id_domicilio)
   join   DBA.d_emp_empresa  a110
     on   (a14.id_emp_empresa = a110.id_emp_empresa)
   join   DBA.afi_localidades    a111
     on   (a19.loca = a111.loca)
   join   DBA.afi_partidos   a112
     on   (a111.partido = a112.partido)
   join   DBA.crm_atributo_quejas    a113
     on   (a12.atributo_id = a113.atributo_id)
   join   DBA.conformidad    a114
     on   (a12.conformidad_comu = a114.id)
   join   DBA.contacto_realizado a115
     on   (a12.contacto_realizado_comu = a115.id)
   join   DBA.d_tie_dia_min  a116
     on   (DATE(a11.registro_fecha_min) = a116.id_tie_dia)
   join   DBA.estado_comu    a117
     on   (a12.estado_comu = a117.id)
   join   DBA.crm_quejas_categ_resol_estado  a118
     on   (a12.estado = a118.estado)
   join   DBA.marcas_adicionales a119
     on   (a14.marca = a119.id)
   join   DBA.crm_queja_motivo   a120
     on   (a12.motivo_id = a120.queja_motivo_id)
   join   DBA.crm_queja_contacto a121
     on   (a12.contacto_id = a121.queja_contacto_id)
   join   DBA.crm_queja_reclamo  a122
     on   (a12.reclamo_id = a122.queja_reclamo_id)
   join   DBA.crm_queja_resolucion   a123
     on   (a12.resolucion_id = a123.queja_resolucion_id)
   join   DBA.satisfaccion   a124
     on   (a12.satisfaccion_comu = a124.id)
   join   DBA.CRM_ESTADOS_MAX    a125
     on   (a11.motivo_id = a125.motivo_id and a11.workflow_max = a125.WORKFLOW)
   join   DBA.crm_d_finalizado   a126
     on   (a11.finalizado = a126.id_finalizado_llamado)
   join   DBA.CRM_GERENCIAS  a127
     on   (a18.GERENCIA = a127.id_gerencia)
   join   DBA.CRM_MEDIOS a128
     on   (a11.medio_id = a128.medio_id)
   join   DBA.CRM_MOTIVOS    a129
     on   (a11.motivo_id = a129.motivo_id)
   join   DBA.d_afi_socio    a130
     on   (a11.ID_AFI_AFILIADO = a130.id_afiliado)
   join   DBA.crm_unidad_de_negocio  a131
     on   (a18.id_unidad_negocio = a131.id_unidad_negocio)
   join   DBA.d_emp_megacuenta   a132
     on   (a110.id_emp_megacuenta = a132.id_emp_megacuenta)
   join   DBA.d_geo_provincia    a133
     on   (a112.provin = a133.id_geo_provincia)
where(parafecha.id_tie_dia >= date("{menor}") and parafecha.id_tie_dia < date("{mayor}")
and a11.motivo_id = 8
and a12.estado in (14)
and a18.GERENCIA in (18, 19))
group by   a11.workflow_id,
   parafecha.id_tie_mes,
   a12.SUBMOTIVO_ID,
   a18.GERENCIA,
   a18.id_unidad_negocio,
   a11.medio_id,
   a12.atributo_id,
   a12.motivo_id,
   a12.contacto_id,
   a12.reclamo_id,
   a12.resolucion_id,
   a11.registro_usuario_max,
   a12.estado,
   a11.workflow_max,
   a11.finalizado,
   string(floor( datediff(second,[registro_fecha_min],[registro_fecha_max]) / 3600 )/24) + ' dias ' + right(replicate('0',2) + string(remainder(floor( datediff(second,[registro_fecha_min],[registro_fecha_max]) / 3600 ),24)),2) + ':' + right(replicate('0',2) + string ( floor( mod(datediff(second,[registro_fecha_min],[registro_fecha_max]), 3600) /60  ) ),2) +  ':' + right(replicate('0',2) + string ( mod( datediff(second,[registro_fecha_min],[registro_fecha_max]), 60) ),2),
   a11.observacion_max,
   a11.observacion_min,
   a12.ALTA_FECHA,
   a12.registro_usuario,
   a12.finalizado,
   a11.prepaga,
   a11.contra,
   a11.inte,
   a11.color_workflow,
   a12.color_queja,
   a12.MODI_FECHA,
   a12.motivo_rechazo,
   a12.solucion,
   a12.INQUIETUD,
   a12.ALTA_FECHA,
   a12.conformidad_comu,
   a12.contacto_realizado_comu,
   a12.estado_comu,
   a12.finalizado_comu,
   a12.motivo_rechazo_comu,
   RTRIM(a12.observacion_comu),
   a12.satisfaccion_comu,
   a12.modi_fecha_comu,
   a19.loca,
   a112.provin,
   a12.lugar_evento,
   a12.prestad,
   a14.id_emp_empresa,
   a11.registro_usuario_min,
   a14.marca,
   a110.id_emp_megacuenta""")

# %%
len(df)
# Out:
# 15443

# %%
df["workflow_id"].nunique()
# Out:
# 15115

# %%
df["workflow_id"].value_counts()
# Out:
# 64439136.0    3
# 68569253.0    3
# 64686087.0    3
# 70157338.0    3
# 69854520.0    3
#              ..
# 66414241.0    1
# 55927937.0    1
# 69912764.0    1
# 31109580.0    1
# 65011771.0    1
# Name: workflow_id, Length: 15115, dtype: int64

# %%
df[df["workflow_id"] == 64439136]
# Out:
#       workflow_id  id_tie_mes  SUBMOTIVO_ID  \
# 9922   64439136.0         275            83
# 9923   64439136.0         275            83
# 9924   64439136.0         275           148
#
#                                                detalle0  \
# 9922  Interior - Contrataciones                     ...
# 9923  Interior - Contrataciones                     ...
# 9924  Contrataciones Prov. Bs.As.                   ...
#
#                              detalle1  atributo_id  \
# 9922  Gestión de Prestadores Interior            0
# 9923  Gestión de Prestadores Interior            0
# 9924           Gestión de Prestadores          901
#
#                         detalle3            registro_usuario_max  \
# 9922                           0  Evelyn Gisele Asernitzky
# 9923                           0  Evelyn Gisele Asernitzky
# 9924  Falta de prestador en zona  Evelyn Gisele Asernitzky
#
#               ALTA_FECHA  afi_prepaga           contra afi_integrante  \
# 9922 2018-11-02 12:09:00            2  77405                       1
# 9923 2018-11-02 16:21:00            2  77405                       1
# 9924 2018-11-05 09:42:00            2  77405                       1
#
#               desc_afi_nombre  color_workflow strDescripcion  \
# 9922  LOSCALZO, SANDRA MARISA               4           Rojo
# 9923  LOSCALZO, SANDRA MARISA               4           Rojo
# 9924  LOSCALZO, SANDRA MARISA               4           Rojo
#
#                                                solucion  \
# 9922
# 9923
# 9924  Marisol G: Me contacto al  291 154182399, soci...
#
#                                               INQUIETUD  finalizado_comu  \
# 9922  Contrataciones interior.Soy de Bahía Blanca y ...                1
# 9923  Contrataciones interior.Soy de Bahía Blanca y ...                1
# 9924  Contrataciones interior.Soy de Bahía Blanca y ...                1
#
#      CustCol_53  id_afi_localidad_particular          deno  id_geo_provincia  \
# 9922    Cerrado                          218  BAHIA BLANCA                 1
# 9923    Cerrado                          218  BAHIA BLANCA                 1
# 9924    Cerrado                          218  BAHIA BLANCA                 1
#
#      desc_geo_provincia         lugar_evento  id_pre_prestador  \
# 9922       BUENOS AIRES  Encuesta #234468096                 0
# 9923       BUENOS AIRES  Encuesta #234468096                 0
# 9924       BUENOS AIRES  Encuesta #234468096                 0
#
#      desc_pre_nombre  id_emp_empresa                     desc_emp_empresa  \
# 9922     Sin Asignar            8467  CORP.DEL COMERC.INDUST.Y SERV.DE BB
# 9923     Sin Asignar            8467  CORP.DEL COMERC.INDUST.Y SERV.DE BB
# 9924     Sin Asignar            8467  CORP.DEL COMERC.INDUST.Y SERV.DE BB
#
#      id_emp_ejecutivo_cuenta  id_emp_cuenta                   reg_username0  \
# 9922         GRISELDAZWENGER          81448  Jimena Garcia Pinan
# 9923         GRISELDAZWENGER          81448  Jimena Garcia Pinan
# 9924         GRISELDAZWENGER          81448  Jimena Garcia Pinan
#
#       id_emp_megacuenta                  desc_emp_megacuenta
# 9922               7829  CORP.DEL COMERC.INDUST.Y SERV.DE BB
# 9923               7829  CORP.DEL COMERC.INDUST.Y SERV.DE BB
# 9924               7829  CORP.DEL COMERC.INDUST.Y SERV.DE BB

# %%
len(df[df["id_pre_prestador"] == 0])
# Out:
# 12915

# %%
#para metrica
df_metrica = df[["workflow_id", "detalle3", "id_pre_prestador","desc_pre_nombre" ]]

# %%
df_metrica = df_metrica[df_metrica["id_pre_prestador"] != 0]

# %%
final = df_metrica.groupby([ "id_pre_prestador","desc_pre_nombre", "detalle3" ])["workflow_id"].nunique().reset_index()

# %%
final.sort_values(by= "workflow_id", ascending = False, inplace=True)

# %%
final.to_excel("quejas.xlsx")

# %%
total_prestador = final.groupby([ "id_pre_prestador","desc_pre_nombre"])["workflow_id"].sum().rename("total_prestador")

# %%
final = final.merge(total_prestador, left_on = "id_pre_prestador" , right_on="id_pre_prestador" )

# %%
final = final.rename(columns= {"id_pre_prestador": "Prestador", "desc_pre_nombre": "Razón social", "detalle3": "Clasificación de casos", "workflow_id": "Q de quejas", "total_prestador": "Total de quejas prestador"})

# %%
final.head(50)
# Out:
#     Prestador                                Razón social  \
# 0        1127                          Hospital Británico
# 1        1127                          Hospital Británico
# 2        1127                          Hospital Británico
# 3        1127                          Hospital Británico
# 4        1127                          Hospital Británico
# 5        1127                          Hospital Británico
# 6        1127                          Hospital Británico
# 7        1127                          Hospital Británico
# 8        1127                          Hospital Británico
# 9        1127                          Hospital Británico
# 10       1127                          Hospital Británico
# 11       1127                          Hospital Británico
# 12       1127                          Hospital Británico
# 13       1127                          Hospital Británico
# 14       1127                          Hospital Británico
# 15       1871                           Diagnóstico Maipú
# 16       1871                           Diagnóstico Maipú
# 17       1871                           Diagnóstico Maipú
# 18       1871                           Diagnóstico Maipú
# 19       1871                           Diagnóstico Maipú
# 20       1871                           Diagnóstico Maipú
# 21       1871                           Diagnóstico Maipú
# 22       1871                           Diagnóstico Maipú
# 23       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 24       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 25       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 26       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 27       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 28       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 29       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 30       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 31       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 32       1436     Centro de Diagnóstico Dr. Enrique Rossi
# 33      28319                                       Vitas
# 34      28319                                       Vitas
# 35      28319                                       Vitas
# 36      28319                                       Vitas
# 37      28319                                       Vitas
# 38      28319                                       Vitas
# 39      28319                                       Vitas
# 40      28319                                       Vitas
# 41      28319                                       Vitas
# 42      28319                                       Vitas
# 43      28319                                       Vitas
# 44      28319                                       Vitas
# 45      82387  API - Asistencia Psicoterapéutica Integral
# 46      82387  API - Asistencia Psicoterapéutica Integral
# 47      82387  API - Asistencia Psicoterapéutica Integral
# 48      82387  API - Asistencia Psicoterapéutica Integral
# 49      82387  API - Asistencia Psicoterapéutica Integral
#
#                                Clasificación de casos  Q de quejas  \
# 0                                   Baja de prestador           43
# 1                         Mala atención del prestador           15
# 2                                   Corte de servicio            7
# 3                      Inconvenientes administrativos            6
# 4                        Mala atención administrativa            6
# 5   Disconformidad del prestador con la prepaga tr...            4
# 6                      Disc. con respuesta del sector            3
# 7                      Facturación de copagos o consu            2
# 8                       Falta de respuesta del sector            2
# 9                          Turno - Demora en at. adm.            2
# 10                     Turno - Demora en otorgamiento            1
# 11                       Turno - Demora en at. médica            1
# 12    Error en la información publicada del Prestador            1
# 13                              Contenido de Cartilla            1
# 14                                     Cobro indebido            1
# 15                                  Baja de prestador           34
# 16                       Mala atención administrativa            9
# 17                        Mala atención del prestador            6
# 18                     Inconvenientes administrativos            3
# 19                                  Corte de servicio            3
# 20                         Turno - Demora en at. adm.            1
# 21                     Disc. con respuesta del sector            1
# 22                              Contenido de Cartilla            1
# 23                                  Baja de prestador           17
# 24                     Inconvenientes administrativos            6
# 25                                     Cobro indebido            2
# 26                                  Corte de servicio            2
# 27                        Mala atención del prestador            2
# 28                              Contenido de Cartilla            1
# 29    Error en la información publicada del Prestador            1
# 30                     Turno - Demora en otorgamiento            1
# 31                       Mala atención administrativa            1
# 32                      Falta de respuesta del sector            1
# 33                        Mala atención del prestador           17
# 34                                     Cobro indebido            4
# 35                     Turno - Demora en otorgamiento            4
# 36                       Mala atención administrativa            2
# 37                     Inconvenientes administrativos            2
# 38                         Falta de prestador en zona            2
# 39                   Dif. para contactar al prestador            2
# 40                     Dif. para contactar al prestad            2
# 41                                 Desconoce atención            1
# 42                              Habitación compartida            1
# 43                      Falta de respuesta del sector            1
# 44                     Disc. con respuesta del sector            1
# 45                        Mala atención del prestador           13
# 46                     Inconvenientes administrativos            6
# 47                                     Cobro indebido            6
# 48                                 Desconoce atención            2
# 49                       Turno - Demora en at. médica            2
#
#     Total de quejas prestador
# 0                          95
# 1                          95
# 2                          95
# 3                          95
# 4                          95
# 5                          95
# 6                          95
# 7                          95
# 8                          95
# 9                          95
# 10                         95
# 11                         95
# 12                         95
# 13                         95
# 14                         95
# 15                         58
# 16                         58
# 17                         58
# 18                         58
# 19                         58
# 20                         58
# 21                         58
# 22                         58
# 23                         34
# 24                         34
# 25                         34
# 26                         34
# 27                         34
# 28                         34
# 29                         34
# 30                         34
# 31                         34
# 32                         34
# 33                         39
# 34                         39
# 35                         39
# 36                         39
# 37                         39
# 38                         39
# 39                         39
# 40                         39
# 41                         39
# 42                         39
# 43                         39
# 44                         39
# 45                         35
# 46                         35
# 47                         35
# 48                         35
# 49                         35
